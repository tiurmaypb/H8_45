# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.1.1

# %%
data_dir = "data/nbaallelo.csv"
df = pd.read_csv(data_dir)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126304          98            1     CLE  Cavaliers  ...  61.312763     GSW
# 126305          99            1     GSW   Warriors  ...  67.029549     CLE
# ...

# %%
num_rows,num_cols = df.shape
print("rows = ", num_rows)
print("column = " ,  num_cols)
# Out:
# rows =  126314
# column =  23

# %%
df["team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
df[["team_id","opp_id"]]
# Out:
#        team_id opp_id
# 0          TRH    NYK
# 1          NYK    TRH
# 2          CHS    NYK
# 3          NYK    CHS
# 4          DTF    WSC
# ...        ...    ...
# 126309     CLE    GSW
# 126310     GSW    CLE
# 126311     CLE    GSW
# 126312     CLE    GSW
# 126313     GSW    CLE
#
# [126314 rows x 2 columns]

# %%
column_name=list(df.columns)
column_name.index("opp_id")
column_name[ 14 : 15] 
cek = df[(column_name[ 14 : 15] )]
cek
# Out:
#        opp_id
# 0         NYK
# 1         TRH
# 2         NYK
# 3         CHS
# 4         WSC
# ...       ...
# 126309    GSW
# 126310    CLE
# 126311    GSW
# 126312    GSW
# 126313    CLE
#
# [126314 rows x 1 columns]

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df.describe(exclude = "number")
# Out:
#              game_id   lg_id date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314    126314  126314  126314  126314   126314
# unique         63157       2     12426     104      53     104       53
# top     199312230MIA     NBA  1/2/2009     BOS  Lakers     BOS   Lakers
# freq               2  118016        30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                H           W  at New York NY
# freq           63138       63157             440

# %%
df.describe(exclude = "string")
# Out:
#             gameorder       game_id   lg_id        _iscopy        year_id  \
# count   126314.000000        126314  126314  126314.000000  126314.000000
# unique            NaN         63157       2            NaN            NaN
# top               NaN  199312230MIA     NBA            NaN            NaN
# freq              NaN             2  118016            NaN            NaN
# mean     31579.000000           NaN     NaN       0.500000    1988.200374
# std      18231.927643           NaN     NaN       0.500002      17.582309
# min          1.000000           NaN     NaN       0.000000    1947.000000
# 25%      15790.000000           NaN     NaN       0.000000    1975.000000
# 50%      31579.000000           NaN     NaN       0.500000    1990.000000
# 75%      47368.000000           NaN     NaN       1.000000    2003.000000
# max      63157.000000           NaN     NaN       1.000000    2015.000000
#
#        date_game     seasongame    is_playoffs team_id fran_id  ...  \
# ...

# %%
df.describe(exclude = "object")
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df.describe(include = "all")

count_lg_id= df.lg_id.value_counts()
count_lg_id
# Out:
#             gameorder       game_id   lg_id        _iscopy        year_id  \
# count   126314.000000        126314  126314  126314.000000  126314.000000
# unique            NaN         63157       2            NaN            NaN
# top               NaN  199312230MIA     NBA            NaN            NaN
# freq              NaN             2  118016            NaN            NaN
# mean     31579.000000           NaN     NaN       0.500000    1988.200374
# std      18231.927643           NaN     NaN       0.500002      17.582309
# min          1.000000           NaN     NaN       0.000000    1947.000000
# 25%      15790.000000           NaN     NaN       0.000000    1975.000000
# 50%      31579.000000           NaN     NaN       0.500000    1990.000000
# 75%      47368.000000           NaN     NaN       1.000000    2003.000000
# max      63157.000000           NaN     NaN       1.000000    2015.000000
#
#        date_game     seasongame    is_playoffs team_id fran_id  ...  \
# ...

# %%
unique_lg_id = df.lg_id.unique()
unique_lg_id
# Out:
# array(['NBA', 'ABA'], dtype=object)

# %%
#DATA STRUCTURE IN PANDAS (data frame & series)
type(df["lg_id"]), type(df[["lg_id"]])
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
students=  pd.Series(data=["a","b","c","d","e"],name ="students")
kelas = pd.Series(data=["q1","q2","q3","q4","q5"], name="kelas")

anggota= pd.DataFrame([students,kelas]).T
anggota
# Out:
#   students kelas
# 0        a    q1
# 1        b    q2
# 2        c    q3
# 3        d    q4
# 4        e    q5

# %%
anggota.to_csv("data/anggota.csv",sep=",", index=False)

# %%
df[(df.win_equiv > 42) &  -(df.year_id>2000)]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 2              2  194611020CHS   NBA        0     1947  11/2/1946           1
# 5              3  194611020DTF   NBA        1     1947  11/2/1946           1
# 13             7  194611040PIT   NBA        1     1947  11/4/1946           2
# 15             8  194611050BOS   NBA        1     1947  11/5/1946           2
# 16             9  194611050DTF   NBA        1     1947  11/5/1946           2
# ...          ...           ...   ...      ...      ...        ...         ...
# 87745      43873  200006140IND   NBA        1     2000  6/14/2000         103
# 87746      43874  200006160IND   NBA        1     2000  6/16/2000         104
# 87747      43874  200006160IND   NBA        0     2000  6/16/2000         104
# 87748      43875  200006190LAL   NBA        0     2000  6/19/2000         105
# 87749      43875  200006190LAL   NBA        1     2000  6/19/2000         105
#
# ...

# %%
df[(df.win_equiv > 42) &  (df.year_id>2000)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 87751       43876  200010310ATL   NBA        1     2001  10/31/2000
# 87753       43877  200010310CHI   NBA        1     2001  10/31/2000
# 87754       43878  200010310DAL   NBA        0     2001  10/31/2000
# 87755       43878  200010310DAL   NBA        1     2001  10/31/2000
# 87756       43879  200010310GSW   NBA        1     2001  10/31/2000
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df.loc[df.team_id == "NYK",["year_id","date_game","is_playoffs","team_id"]]
# Out:
#         year_id   date_game  is_playoffs team_id
# 1          1947   11/1/1946            0     NYK
# 3          1947   11/2/1946            0     NYK
# 23         1947   11/7/1946            0     NYK
# 37         1947  11/11/1946            0     NYK
# 54         1947  11/16/1946            0     NYK
# ...         ...         ...          ...     ...
# 126025     2015    4/8/2015            0     NYK
# 126056     2015   4/10/2015            0     NYK
# 126072     2015   4/11/2015            0     NYK
# 126094     2015   4/13/2015            0     NYK
# 126147     2015   4/15/2015            0     NYK
#
# [5769 rows x 4 columns]

# %%
df.loc[df.team_id == ("NYK"),["year_id","date_game","is_playoffs","team_id"]]
# Out:
#         year_id   date_game  is_playoffs team_id
# 1          1947   11/1/1946            0     NYK
# 3          1947   11/2/1946            0     NYK
# 23         1947   11/7/1946            0     NYK
# 37         1947  11/11/1946            0     NYK
# 54         1947  11/16/1946            0     NYK
# ...         ...         ...          ...     ...
# 126025     2015    4/8/2015            0     NYK
# 126056     2015   4/10/2015            0     NYK
# 126072     2015   4/11/2015            0     NYK
# 126094     2015   4/13/2015            0     NYK
# 126147     2015   4/15/2015            0     NYK
#
# [5769 rows x 4 columns]

# %%
df.loc[ :10 ,["year_id","date_game","is_playoffs","team_id"]]
# Out:
#     year_id  date_game  is_playoffs team_id
# 0      1947  11/1/1946            0     TRH
# 1      1947  11/1/1946            0     NYK
# 2      1947  11/2/1946            0     CHS
# 3      1947  11/2/1946            0     NYK
# 4      1947  11/2/1946            0     DTF
# 5      1947  11/2/1946            0     WSC
# 6      1947  11/2/1946            0     BOS
# 7      1947  11/2/1946            0     PRO
# 8      1947  11/2/1946            0     PIT
# 9      1947  11/2/1946            0     STB
# 10     1947  11/3/1946            0     TRH

# %%
test = df.loc[df.team_id == ("NYK"),["year_id","date_game","is_playoffs","team_id"]]
test
# Out:
#         year_id   date_game  is_playoffs team_id
# 1          1947   11/1/1946            0     NYK
# 3          1947   11/2/1946            0     NYK
# 23         1947   11/7/1946            0     NYK
# 37         1947  11/11/1946            0     NYK
# 54         1947  11/16/1946            0     NYK
# ...         ...         ...          ...     ...
# 126025     2015    4/8/2015            0     NYK
# 126056     2015   4/10/2015            0     NYK
# 126072     2015   4/11/2015            0     NYK
# 126094     2015   4/13/2015            0     NYK
# 126147     2015   4/15/2015            0     NYK
#
# [5769 rows x 4 columns]

# %%
df.loc[df.team_id.isin(["NYK","SAC","DET"]),["team_id","fran_id","opp_id"]]
# Out:
#        team_id  fran_id opp_id
# 1          NYK   Knicks    TRH
# 3          NYK   Knicks    CHS
# 23         NYK   Knicks    STB
# 37         NYK   Knicks    CHS
# 54         NYK   Knicks    PIT
# ...        ...      ...    ...
# 126101     DET  Pistons    CLE
# 126114     SAC    Kings    LAL
# 126136     SAC    Kings    LAL
# 126146     DET  Pistons    NYK
# 126147     NYK   Knicks    DET
#
# [13242 rows x 3 columns]

# %%
df[df.opp_fran.str.endswith("s")]
df[df.team_id.str.startswith("N")]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1               1  194611010TRH   NBA        1     1947   11/1/1946
# 3               2  194611020CHS   NBA        1     1947   11/2/1946
# 23             12  194611070STB   NBA        1     1947   11/7/1946
# 37             19  194611110NYK   NBA        0     1947  11/11/1946
# 54             28  194611160NYK   NBA        0     1947  11/16/1946
# ...           ...           ...   ...      ...      ...         ...
# 126147      63074  201504150NYK   NBA        0     2015   4/15/2015
# 126154      63078  201504180GSW   NBA        1     2015   4/18/2015
# 126170      63086  201504200GSW   NBA        1     2015   4/20/2015
# 126189      63095  201504230NOP   NBA        0     2015   4/23/2015
# 126201      63101  201504250NOP   NBA        0     2015   4/25/2015
#
#         seasongame  is_playoffs team_id   fran_id  ...  win_equiv  opp_id  \
# 1                1            0     NYK    Knicks  ...  41.705170     TRH
# ...

# %%
df.game_id= df.date_game.astype("object").str.split("/").str.join("")+df.team_id+df.lg_id
df.game_id
#hasilnya sama kayak ini
df[game_id]= df.date_game.astype("object").str.split("/").str.join("")+df.team_id+df.lg_id
df[game_id]
# Out:
# 0         1111946TRHNBA
# 1         1111946NYKNBA
# 2         1121946CHSNBA
# 3         1121946NYKNBA
# 4         1121946DTFNBA
#               ...
# 126309    6112015CLENBA
# 126310    6142015GSWNBA
# 126311    6142015CLENBA
# 126312    6162015CLENBA
# 126313    6162015GSWNBA
# Name: game_id, Length: 126314, dtype: object

# %%
df.isna()
# Out:
#         gameorder  game_id  lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           False    False  False    False    False      False       False
# 1           False    False  False    False    False      False       False
# 2           False    False  False    False    False      False       False
# 3           False    False  False    False    False      False       False
# 4           False    False  False    False    False      False       False
# ...           ...      ...    ...      ...      ...        ...         ...
# 126309      False    False  False    False    False      False       False
# 126310      False    False  False    False    False      False       False
# 126311      False    False  False    False    False      False       False
# 126312      False    False  False    False    False      False       False
# 126313      False    False  False    False    False      False       False
#
# ...

# %%
df.notes.isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 126309    True
# 126310    True
# 126311    True
# 126312    True
# 126313    True
# Name: notes, Length: 126314, dtype: bool

# %%
df[df.notes.notna()]
# Out:
#         gameorder         game_id lg_id  _iscopy  year_id   date_game  \
# 930           466   1301948WSCNBA   NBA        1     1948   1/30/1948
# 931           466   1301948BLBNBA   NBA        0     1948   1/30/1948
# 1084          543   3231948WSCNBA   NBA        1     1948   3/23/1948
# 1085          543   3231948CHSNBA   NBA        0     1948   3/23/1948
# 1088          545   3251948BLBNBA   NBA        1     1948   3/25/1948
# ...           ...             ...   ...      ...      ...         ...
# 122207      61104   1162014ATLNBA   NBA        0     2014   1/16/2014
# 123916      61959  11122014HOUNBA   NBA        1     2015  11/12/2014
# 123917      61959  11122014MINNBA   NBA        0     2015  11/12/2014
# 124862      62432   1152015MILNBA   NBA        0     2015   1/15/2015
# 124863      62432   1152015NYKNBA   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df.fillna("-999999999999999")
# Out:
#         gameorder        game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  1111946TRHNBA   NBA        0     1947  11/1/1946
# 1               1  1111946NYKNBA   NBA        1     1947  11/1/1946
# 2               2  1121946CHSNBA   NBA        0     1947  11/2/1946
# 3               2  1121946NYKNBA   NBA        1     1947  11/2/1946
# 4               3  1121946DTFNBA   NBA        0     1947  11/2/1946
# ...           ...            ...   ...      ...      ...        ...
# 126309      63155  6112015CLENBA   NBA        0     2015  6/11/2015
# 126310      63156  6142015GSWNBA   NBA        0     2015  6/14/2015
# 126311      63156  6142015CLENBA   NBA        1     2015  6/14/2015
# 126312      63157  6162015CLENBA   NBA        0     2015  6/16/2015
# 126313      63157  6162015GSWNBA   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df.fillna({"notes": -999})
# Out:
#         gameorder        game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  1111946TRHNBA   NBA        0     1947  11/1/1946
# 1               1  1111946NYKNBA   NBA        1     1947  11/1/1946
# 2               2  1121946CHSNBA   NBA        0     1947  11/2/1946
# 3               2  1121946NYKNBA   NBA        1     1947  11/2/1946
# 4               3  1121946DTFNBA   NBA        0     1947  11/2/1946
# ...           ...            ...   ...      ...      ...        ...
# 126309      63155  6112015CLENBA   NBA        0     2015  6/11/2015
# 126310      63156  6142015GSWNBA   NBA        0     2015  6/14/2015
# 126311      63156  6142015CLENBA   NBA        1     2015  6/14/2015
# 126312      63157  6162015CLENBA   NBA        0     2015  6/16/2015
# 126313      63157  6162015GSWNBA   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...
